# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('customer_shopping_behavior.csv')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             70000 non-null  int64
#  1   Age                     70000 non-null  int64
#  2   Gender                  70000 non-null  str
#  3   Item Purchased          70000 non-null  str
#  4   Category                70000 non-null  str
#  5   Purchase Amount (USD)   70000 non-null  int64
#  6   Location                70000 non-null  str
#  7   Size                    70000 non-null  str
#  8   Color                   70000 non-null  str
#  9   Season                  70000 non-null  str
#  10  Review Rating           69326 non-null  float64
#  11  Subscription Status     70000 non-null  str
#  12  Shipping Type           70000 non-null  str
#  13  Discount Applied        70000 non-null  str
#  14  Promo Code Used         70000 non-null  str
#  15  Previous Purchases      70000 non-null  int64
#  16  Payment Method          70000 non-null  str
#  17  Frequency of Purchases  70000 non-null  str
# dtypes: float64(1), int64(4), str(13)
# memory usage: 9.6 MB

# %%
df.describe(include='all')
# Out:
#          Customer ID           Age Gender Item Purchased  Category  \
# count   70000.000000  70000.000000  70000          70000     70000
# unique           NaN           NaN      2             25         4
# top              NaN           NaN   Male         Blouse  Clothing
# freq             NaN           NaN  47470           3129     31269
# mean    35000.500000     44.090871    NaN            NaN       NaN
# std     20207.403759     15.224922    NaN            NaN       NaN
# min         1.000000     18.000000    NaN            NaN       NaN
# 25%     17500.750000     31.000000    NaN            NaN       NaN
# 50%     35000.500000     44.000000    NaN            NaN       NaN
# 75%     52500.250000     57.000000    NaN            NaN       NaN
# max     70000.000000     70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)    Location   Size  Color  Season  \
# count            70000.000000       70000  70000  70000   70000
# unique                    NaN          50      4     25       4
# top                       NaN  California      M  Olive  Spring
# freq                      NaN        1734  31714   3175   17955
# mean                59.551957         NaN    NaN    NaN     NaN
# std                 23.663321         NaN    NaN    NaN     NaN
# min                 20.000000         NaN    NaN    NaN     NaN
# 25%                 38.000000         NaN    NaN    NaN     NaN
# 50%                 60.000000         NaN    NaN    NaN     NaN
# 75%                 80.000000         NaN    NaN    NaN     NaN
# max                100.000000         NaN    NaN    NaN     NaN
#
#         Review Rating Subscription Status  Shipping Type Discount Applied  \
# count    69326.000000               70000          70000            70000
# unique            NaN                   2              6                2
# top               NaN                  No  Free Shipping               No
# freq              NaN               51237          12204            39976
# mean         3.749358                 NaN            NaN              NaN
# std          0.721551                 NaN            NaN              NaN
# min          2.500000                 NaN            NaN              NaN
# 25%          3.125287                 NaN            NaN              NaN
# 50%          3.753479                 NaN            NaN              NaN
# 75%          4.364168                 NaN            NaN              NaN
# max          5.000000                 NaN            NaN              NaN
#
#        Promo Code Used  Previous Purchases Payment Method  \
# count            70000        70000.000000          70000
# unique               2                 NaN              6
# top                 No                 NaN         PayPal
# freq             39976                 NaN          12211
# mean               NaN           25.446314            NaN
# std                NaN           14.463490            NaN
# min                NaN            1.000000            NaN
# 25%                NaN           13.000000            NaN
# 50%                NaN           26.000000            NaN
# 75%                NaN           38.000000            NaN
# max                NaN           50.000000            NaN
#
#        Frequency of Purchases
# count                   70000
# unique                      7
# top            Every 3 Months
# freq                    10579
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating             674
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df['Review Rating']= df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df=df.rename(columns={'purchase_amount_(usd)': 'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
# Create a column age_group
labels= ['Young Adult', 'Adult','Middle-aged','Senior']
df['age_group']=pd.qcut(df['age'],q=4, labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
# Create column purchase_frequency_days

frequency_mapping={
    'Fortnightly': 14,
    'Weekly':7,
    'Monthly':30,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}

df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used', axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Step1: Connect to PostgreSQL
# Replace placeholders with your actual details
username= "postgres"  #default user
password = quote_plus("#Panu@_1167")
host="localhost"
port="5432"
database="customer_shopping_behavior"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

#Step2: Load Dataframe into PostgreSQL
table_name="customer" #Choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data succesfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data succesfully loaded into table 'customer' in database 'customer_shopping_behavior'.
